# %%
import optuna
import plotly.express as px

import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import plotly.express as px
import xgboost as xgb
import shap
import plotly.express as px

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score


random_seed = 42
np.random.seed(random_seed)
random.seed(random_seed)

# %%
def define_files():
    files = {
        "air_pollution_death": "data/air_pollution_death.csv",
        "transportation": 'data/road-transportation_country_emissions.csv',
        "coal": 'data/coal-mining_country_emissions.csv',
        "cropland": 'data/cropland-fires_country_emissions.csv',
        "residential_commercial": 'data/residential-and-commercial-onsite-fuel-usage_country_emissions.csv',
        "forest_clearing": 'data/forest-land-clearing_country_emissions.csv',
        "petrochemicals": 'data/petrochemicals_country_emissions.csv',
        "electricity_generation": 'data/electricity-generation_country_emissions.csv',
        "incineration_open_burning": 'data/incineration-and-open-burning-of-waste_country_emissions.csv',
        "health_expenditure": 'data/health-expenditure.csv',
        "urban_population": 'data/urban-population.csv'
    }
    return files

# %%
def clean_column_names(df):
    """Removes quotes and trims spaces from column names."""
    df.columns = df.columns.str.replace('"', '', regex=False).str.replace("'", "", regex=False).str.strip()
    return df

# %%
def get_common_country_codes(files, env_factors, socio_factors, air_pollution_file):
    env_country_codes = set()
    socio_country_codes = set()
    air_pollution_country_codes = set()

    # Extract unique country codes from environmental factors (using 'iso3_country')
    for factor in env_factors:
        try:
            df = pd.read_csv(files[factor], on_bad_lines='skip')
            df = clean_column_names(df)

            if "iso3_country" in df.columns:
                env_country_codes.update(df["iso3_country"].dropna().unique())
            else:
                print(f"WARNING: 'iso3_country' column not found in {factor} dataset!")
        except Exception as e:
            print(f"Error processing {factor}: {e}")

    # Extract unique country codes from socio-economic factors (using 'Country Code')
    for factor in socio_factors:
        try:
            skip_rows = 3  # Skip metadata rows
            df = pd.read_csv(files[factor], skiprows=skip_rows, on_bad_lines='skip')
            df = clean_column_names(df)

            if "Country Code" in df.columns:
                socio_country_codes.update(df["Country Code"].dropna().unique())
            else:
                print(f"WARNING: 'Country Code' column not found in {factor} dataset!")
        except Exception as e:
            print(f"Error processing {factor}: {e}")

    # Extract unique country codes from air pollution data (using 'SpatialDimValueCode')
    try:
        df = pd.read_csv(files[air_pollution_file], on_bad_lines='skip')
        df = clean_column_names(df)

        if "SpatialDimValueCode" in df.columns:
            air_pollution_country_codes.update(df["SpatialDimValueCode"].dropna().unique())
        else:
            print(f"WARNING: 'SpatialDimValueCode' column not found in {air_pollution_file} dataset!")
    except Exception as e:
        print(f"Error processing {air_pollution_file}: {e}")

    # Find the common country codes across all datasets
    common_country_codes = sorted(
        env_country_codes.intersection(socio_country_codes).intersection(air_pollution_country_codes)
    )

    print(f"Common Country Codes Found: {common_country_codes}")
    return common_country_codes

# %%
def load_and_filter_data(files, common_country_codes):
    air_pollution_df = pd.read_csv(files["air_pollution_death"], on_bad_lines='skip')
    air_pollution_df = clean_column_names(air_pollution_df)

    if "SpatialDimValueCode" not in air_pollution_df.columns:
        print("ERROR: 'SpatialDimValueCode' column missing in air_pollution_death dataset!")
        return None, None, None

    # Filter data for common country codes and 2018
    air_pollution_df = air_pollution_df[(
        air_pollution_df["SpatialDimValueCode"].isin(common_country_codes)) & 
        (air_pollution_df["Period"] == 2018) & 
        (air_pollution_df["Dim1"] == "Both sexes")
    ]
    
    env_data = {}
    environment_factor_files_list = [
        'transportation', 'coal', 'cropland', 'residential_commercial', 
        'forest_clearing', 'petrochemicals', 'electricity_generation', 
        'incineration_open_burning'
    ]
    
    for factor in environment_factor_files_list:
        df = pd.read_csv(files[factor], on_bad_lines='skip')
        df = clean_column_names(df)
        if "iso3_country" in df.columns:
            df = df[df["iso3_country"].isin(common_country_codes)]
        else:
            print(f"WARNING: 'iso3_country' not found in {factor} dataset!")
        env_data[factor] = df
    
    socio_data = {}
    socioeconomic_files_list = ['health_expenditure', 'urban_population']
    
    for factor in socioeconomic_files_list:
        skip_rows = 3  # Skip metadata rows
        df = pd.read_csv(files[factor], skiprows=skip_rows, on_bad_lines='skip')
        df = clean_column_names(df)
        if "Country Code" in df.columns:
            df = df[df["Country Code"].isin(common_country_codes)]
        else:
            print(f"WARNING: 'Country Code' not found in {factor} dataset!")
        socio_data[factor] = df
    
    return air_pollution_df, env_data, socio_data

# %%
def merge_data(air_pollution_df, env_data, socio_data):
    merged_df = air_pollution_df.copy()

    for df in env_data.items():
        if "iso3_country" in df.columns and "Value" in df.columns:
            merged_df = pd.merge(merged_df, df[['iso3_country', 'Value']], on='iso3_country', how='outer')

    for df in socio_data.items():
        if "Country Code" in df.columns and "Value" in df.columns:
            merged_df = pd.merge(merged_df, df[['Country Code', 'Value']], on='Country Code', how='outer')
    return merged_df

# %%
def process_environment_and_socioeconomic_data(env_data, socio_data, common_country_codes):
    environment_results = []
    socioeconomic_results = []

    # **(B) Processing Environment Data**
    for factor, df in env_data.items():
        if "iso3_country" in df.columns and "start_time" in df.columns and "emissions_quantity" in df.columns:
            try:
                df["start_time"] = pd.to_datetime(df["start_time"], errors="coerce")  # Ensure proper date format
                df_filtered = df[(
                    df["iso3_country"].isin(common_country_codes)) & 
                    (df["start_time"] >= "2018-01-01")
                ]
                df_grouped = df_filtered.groupby("iso3_country", as_index=False)["emissions_quantity"].sum()
                df_grouped.rename(columns={"iso3_country": "Country Code", "emissions_quantity": factor}, inplace=True)
                environment_results.append(df_grouped)
            except Exception as e:
                print(f"Error processing {factor}: {e}")
        else:
            print(f"WARNING: Missing required columns in {factor} dataset!")

    # **(C) Processing Socioeconomic Data**
    for factor, df in socio_data.items():
        if "Country Code" in df.columns and "2018" in df.columns:
            try:
                df_filtered = df[df["Country Code"].isin(common_country_codes)][["Country Code", "2018"]]
                df_filtered.rename(columns={"2018": factor}, inplace=True)
                socioeconomic_results.append(df_filtered)
            except Exception as e:
                print(f"Error processing {factor}: {e}")
        else:
            print(f"WARNING: Missing required columns in {factor} dataset!")

    return environment_results, socioeconomic_results

# %%
def merge_environment_socioeconomic_air_pollution_data(environment_results, socioeconomic_results, air_pollution_df):
    # **(A) Merge environmental data**
    environment_data_combined = environment_results[0]
    for env_df in environment_results[1:]:
        environment_data_combined = pd.merge(environment_data_combined, env_df, on="Country Code", how="outer")

    # **(B) Merge socioeconomic data**
    socioeconomic_data_combined = socioeconomic_results[0]
    for socio_df in socioeconomic_results[1:]:
        socioeconomic_data_combined = pd.merge(socioeconomic_data_combined, socio_df, on="Country Code", how="outer")

    # **(C) Merge environmental and socioeconomic data**
    merged_env_socio_data = pd.merge(environment_data_combined, socioeconomic_data_combined, on="Country Code", how="outer")

    # **(D) Aggregate air pollution deaths per country**
    air_pollution_agg = air_pollution_df.groupby("SpatialDimValueCode", as_index=False)["FactValueNumeric"].sum()
    air_pollution_agg.rename(columns={"SpatialDimValueCode": "Country Code"}, inplace=True)

    # **(E) Merge with aggregated air pollution data**
    merged_data_with_deaths = pd.merge(merged_env_socio_data, air_pollution_agg, on='Country Code', how='outer')

    # **(F) Rename columns to meaningful names**
    merged_data_with_deaths.rename(columns={
        'name_x': 'environmental_value',
        'name_y': 'socioeconomic_value',
        'Value': 'air_pollution_deaths'
    }, inplace=True)

    return merged_data_with_deaths

# %%
def train_model(df):
    # Prepare dataset
    X = df.drop(['SpatialDimValueCode', 'Air Pollution Deaths', 'FactValueNumeric'], axis=1, errors='ignore')
    X = X.select_dtypes(include=[np.number])
    y = df['FactValueNumeric'].astype(float)

    # Train-Test Split
    X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2, random_state=random_seed)

    # Standardize features
    scaler = StandardScaler()
    X_train_val = pd.DataFrame(scaler.fit_transform(X_train_val), columns=X_train_val.columns)
    X_test = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

    # Optuna optimization function
    def objective(trial):
        params = {
            'n_estimators': trial.suggest_int('n_estimators', 1500, 2200, step=100),  # More boosting rounds
            'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.009, log=True),  # More precise learning
            'max_depth': trial.suggest_int('max_depth', 6, 7),  # Balanced complexity
            'min_child_weight': trial.suggest_int('min_child_weight', 6, 10),  # Prevent overfitting
            'subsample': trial.suggest_float('subsample', 0.95, 1.0),  # Use more training data
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.95, 1.0),  # More features per tree
            'reg_alpha': trial.suggest_float('reg_alpha', 2, 8),  # Reduce restriction
            'reg_lambda': trial.suggest_float('reg_lambda', 2, 8),  # Reduce restriction
            'gamma': trial.suggest_float('gamma', 1, 4),  # Allow better splits
            'random_state': random_seed,
            'early_stopping_rounds': 50
        }

        # Train XGBoost model
        model = xgb.XGBRegressor(**params)
        model.fit(X_train_val, y_train_val, eval_set=[(X_test, y_test)], verbose=False)

        # Evaluate R^2 Score
        test_pred = model.predict(X_test)
        return r2_score(y_test, test_pred)

    # Run Optuna Optimization
    study = optuna.create_study(direction='maximize')
    study.optimize(objective, n_trials=100)  # Run 50 trialsc

    # Get best parameters
    best_params = study.best_params
    print("Best parameters found: ", best_params)

    # Train final model with best parameters
    xgb_model = xgb.XGBRegressor(**best_params)
    xgb_model.fit(X_train_val, y_train_val, eval_set=[(X_test, y_test)], verbose=True)
 
    # Final model evaluation
    train_r2 = r2_score(y_train_val, xgb_model.predict(X_train_val))
    test_r2 = r2_score(y_test, xgb_model.predict(X_test))

    print(f'Final Train R^2 Score: {train_r2}')
    print(f'Final Test R^2 Score: {test_r2}')

    # results = xgb_model.evals_result()
 
    # # Convert to DataFrame
    # iterations = range(len(results['validation_0']['rmse']))  # XGBoost logs RMSE by default
    # train_r2_list = [r2_score(y_train_val, xgb_model.predict(X_train_val, iteration_range=(0, i+1))) for i in iterations]
    # test_r2_list = [r2_score(y_test, xgb_model.predict(X_test, iteration_range=(0, i+1))) for i in iterations]
    
    # # Plot
    # plt.figure(figsize=(10, 5))
    # plt.plot(iterations, train_r2_list, label="Train R²")
    # plt.plot(iterations, test_r2_list, label="Test R²")
    
    # plt.xlabel("Iteration")
    # plt.ylabel("R² Score")
    # plt.title("Train vs Test R² Score Over Iterations")
    # plt.legend()
    # plt.grid(True)
    # plt.show()

    return xgb_model, X_train_val, y_train_val, train_r2, test_r2

# %%
def generate_beeswarm_plot(model, X_train_val):
    # Rename columns: replace underscores with spaces and capitalize
    X_train_val = X_train_val.rename(columns=lambda x: x.replace('_', ' ').title())

    # Generate SHAP values
    explainer = shap.Explainer(model, X_train_val)
    shap_values = explainer(X_train_val)

    # Generate SHAP plot without displaying it
    shap.summary_plot(shap_values, X_train_val, plot_type="dot", show=False)

    # Save the current figure generated by SHAP
    fig = plt.gcf()  # Get the current figure
    fig.savefig("beeswarm_plot.png", bbox_inches='tight')  

    plt.close(fig)

# %%
def generate_html_file(merged_data, train_r2, test_r2):
    merged_data['Country Code'] = merged_data['Country Code'].str.strip()  # Ensure clean data
    
    factors = [col for col in merged_data.columns if col not in ['Country Code', 'FactValueNumeric']]
    data_without_chn_ind = merged_data[~merged_data['Country Code'].isin(['CHN', 'IND'])]

    scatter_html_blocks = []                      # For all countries
    scatter_html_blocks_without_chn_ind = []      # Excluding CHN and IND

    for factor in factors:
        # Scatter plots with CHN & IND
        correlation_all = merged_data['FactValueNumeric'].corr(merged_data[factor])
        fig_all = px.scatter(
            merged_data,
            x=factor,
            y='FactValueNumeric',
            text="Country Code",
            title=f"Air Pollution Deaths vs {factor.replace('_', ' ').title()} (Corr: {round(correlation_all, 2)})",
            labels={'FactValueNumeric': 'Air Pollution Deaths'}
        )
        scatter_html_blocks.append((factor, fig_all.to_html(full_html=False)))

        # Scatter plots without CHN & IND
        correlation_without = data_without_chn_ind['FactValueNumeric'].corr(data_without_chn_ind[factor])
        fig_without = px.scatter(
            data_without_chn_ind,
            x=factor,
            y='FactValueNumeric',
            text="Country Code",
            title=f"Air Pollution Deaths vs {factor.replace('_', ' ').title()} (Excl. CHN & IND, Corr: {round(correlation_without, 2)})",
            labels={'FactValueNumeric': 'Air Pollution Deaths'}
        )
        scatter_html_blocks_without_chn_ind.append((factor, fig_without.to_html(full_html=False)))

        choropleth_map = px.choropleth(
            merged_data,
            locations="Country Code",
            color="FactValueNumeric",
            hover_data={"Country Code": True, "FactValueNumeric": True},
            color_continuous_scale=px.colors.sequential.Reds,
            labels={"FactValueNumeric": "Air Pollution Deaths"}  # Add label here
        ).to_html(full_html=False)

        with open("coding_test_output.html", "w", encoding="utf-8") as f:
            f.write(f"""
            <!DOCTYPE html>
            <html>
                <head>
                    <meta charset="UTF-8">
                    <title>Air Pollution and Emissions Analysis</title>
                    <link href="https://fonts.googleapis.com/css2?family=Montserrat:wght@400;700&display=swap" rel="stylesheet">
                    <style>
                        body {{
                            font-family: 'Montserrat', sans-serif;
                        }}
                        .container {{
                            display: flex;
                            align-items: center;
                            justify-content: space-around;
                            gap: 20px;
                        }}
                        .radio-buttons {{
                            display: flex;
                            flex-direction: column;
                            min-width: 150px;
                        }}
                        select {{
                            padding: 3px;
                        }}
                        .option-style {{
                            padding: 2px;
                        }}
                        .scatter-plot {{
                            display: none;
                        }}
                    </style>
                    <script>
                        let selectedFactorIndex = 0; // Track the selected factor

                        function showPlot(factorIndex) {{
                            selectedFactorIndex = factorIndex;
                            const withCHN = document.getElementsByClassName('with-china-india');
                            const withoutCHN = document.getElementsByClassName('without-china-india');
                            const selection = document.getElementById("filter-select").value;

                            // Hide all plots
                            for (let plot of withCHN) plot.style.display = 'none';
                            for (let plot of withoutCHN) plot.style.display = 'none';

                            // Determine active dataset
                            const activeClass = selection === 'with_china_india' ? withCHN : withoutCHN;
                            // Ensure selectedFactorIndex is within bounds
                            if (selectedFactorIndex >= activeClass.length) {{
                                selectedFactorIndex = 0; // Reset if out of bounds
                            }}
                            // Display the corresponding plot
                            if(activeClass === withoutCHN){{
                                if(selectedFactorIndex === 0){{
                                    selectedFactorIndex = "plot_without_"+selectedFactorIndex;
                                }}
                                let new_id = selectedFactorIndex.split("_")
                                let active_plot = "plot_without_"+new_id[new_id.length - 1];
                                activeClass[active_plot].style.display = 'block';
                            }}else if(activeClass === withCHN){{
                                if(selectedFactorIndex === 0){{
                                    selectedFactorIndex = "plot_with_"+selectedFactorIndex;
                                }}
                                let new_id = selectedFactorIndex.split("_")
                                let active_plot = "plot_with_"+new_id[new_id.length - 1];
                                activeClass[active_plot].style.display = 'block';
                            }}
                            if (activeClass[selectedFactorIndex]) {{
                                activeClass[selectedFactorIndex].style.display = 'block';
                            }}
                        }}

                        function toggleCountries() {{
                            showPlot(selectedFactorIndex); // Maintain the same factor when toggling
                        }}
                    </script>
                </head>
                <body>
                    <h2 style="text-align:center; margin:20px;">Air Pollution Deaths by Country</h2>
                    {choropleth_map}
                    <hr style="width:80%"/>
                    <h2 style="text-align:center;">Scatter Plots</h2>
                    <div class="container">
                        <div class="radio-buttons">
            """)

            # Add radio buttons for each scatter plot
            for i, (factor, scatter_html) in enumerate(scatter_html_blocks):
                plot_id_with = f"plot_with_{i}"
                # plot_id_without = f"plot_without_{i}"
                checked_attr = 'checked' if i == 0 else ''
                f.write(f"""
                    <label>
                        <input type="radio" name="scatter" onclick="showPlot('{plot_id_with}')" {checked_attr}>
                        {factor.replace("_", " ").title()}
                    </label>
                """)

            f.write("""
                <div class="option-container">
                        <br />
                        <label for="filter-select">Outlier Removal Option:</label>
                        <select id="filter-select" onchange="toggleCountries()">
                            <option class="option-style" value="with_china_india" selected>Include CHN & IND</option>
                            <option class="option-style" value="without_china_india">Exclude CHN & IND</option>
                        </select>
                    </div>
                </div> <!-- End of radio-buttons -->
            """)

            # Display scatter plots WITH CHN & IND
            for i, (factor, scatter_html) in enumerate(scatter_html_blocks):
                plot_id = f"plot_with_{i}"
                display_style = "block" if i == 0 else "none"
                f.write(f"""
                    <div id="{plot_id}" class="scatter-plot with-china-india" style="display: {display_style};">
                        {scatter_html}
                    </div>
                """)

            # Display scatter plots WITHOUT CHN & IND (hidden initially)
            for i, (factor, scatter_html) in enumerate(scatter_html_blocks_without_chn_ind):
                plot_id = f"plot_without_{i}"
                f.write(f"""
                    <div id="{plot_id}" class="scatter-plot without-china-india" style="display: none;">
                        {scatter_html}
                    </div>
                """)

            f.write(f"""
                    </div>
                    <hr style="width:80%"/>
                    <div style="text-align: center; margin:50px;">
                        <h2>Adjusted R² Score</h2>
                        <p>
                            Train R²: <strong>{train_r2:.4f}</strong><br />
                            Test R²: <strong>{test_r2:.4f}</strong>
                        </p>
                    </div>
                    <hr style="width:80%"/>
                    <div>
                        <h2 style="text-align:center;">SHAP Beeswarm Plot</h2>
                        <img src="./beeswarm_plot.png" alt="SHAP Beeswarm Plot" style="width:80%; height:auto;">
                    </div>
                </body>
            </html>
            """)

# %%
def start_predict_xgboost():
    random_seed = 42
    np.random.seed(random_seed)
    random.seed(random_seed)

    print("Defining files...")
    files = define_files()
    print("Files defined successfully!")

    print("Getting common country codes...")
    environment_factor_files_list = [
        'transportation', 'coal', 'cropland', 'residential_commercial', 
        'forest_clearing', 'petrochemicals', 'electricity_generation', 
        'incineration_open_burning'
    ]
    socioeconomic_files_list = ['health_expenditure', 'urban_population']
    common_country_codes = get_common_country_codes(files, environment_factor_files_list, socioeconomic_files_list, "air_pollution_death")

    print("Loading and filtering data...")
    air_pollution_df, env_data, socio_data = load_and_filter_data(files, common_country_codes)

    if air_pollution_df is None:
        print("ERROR: Data loading failed.")
        return

    print("Processing environment and socioeconomic data...")
    environment_results, socioeconomic_results = process_environment_and_socioeconomic_data(env_data, socio_data, common_country_codes)
    
    # print("socioeconomic_results->>>>>>>>>>>>>>>\n",socioeconomic_results)

    # **Merge environment, socioeconomic, and air pollution data**
    print("Merging environment, socioeconomic, and air pollution data...")
    merged_data = merge_environment_socioeconomic_air_pollution_data(environment_results, socioeconomic_results, air_pollution_df)
    merged_data_with_outliers = merge_environment_socioeconomic_air_pollution_data(environment_results, socioeconomic_results, air_pollution_df)
    # CHN and IND should be optional it can be toogled from include and exclude
    merged_data_with_outliers = merged_data_with_outliers[merged_data_with_outliers['Country Code'] != 'CHN']
    merged_data_with_outliers = merged_data_with_outliers[merged_data_with_outliers['Country Code'] != 'IND']

    # if exclude_countries:
        # merged_data = merged_data[~merged_data['Country Code'].isin(['CHN', 'IND'])]


    print(f"Merged data has {merged_data.shape[0]} rows and {merged_data.shape[1]} columns.")
    print(merged_data)  # Optional: Check the first few rows of the merged dataframe

    model, X_train_val, y_train_val, train_r2, test_r2 = train_model(merged_data)
    model_with, X_train_val_with, y_train_val_with, train_r2_with, test_r2_with = train_model(merged_data_with_outliers)

    generate_beeswarm_plot(model_with, X_train_val_with)
    
    generate_html_file(merged_data, train_r2_with, test_r2_with)

    # Generate merge data
    # if merged_data is None or merged_data.empty:
    #     print("ERROR: merged_data is empty or not defined.")
    # else:
    #     merged_data.to_csv("merged_data.csv", index=False)
    #     print("merged_data.csv saved successfully!")

# %%
if __name__ == "__main__":
    print("Calling start_predict_xgboost()...")
    start_predict_xgboost()
    print("Script execution complete!")
# Out:
# Calling start_predict_xgboost()...
# Defining files...
# Files defined successfully!
# Getting common country codes...
# Common Country Codes Found: ['AFG', 'AGO', 'ALB', 'ARE', 'ARG', 'ARM', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA', 'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BOL', 'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE', 'CHL', 'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COL', 'COM', 'CPV', 'CRI', 'CUB', 'CYP', 'CZE', 'DEU', 'DJI', 'DNK', 'DOM', 'DZA', 'ECU', 'EGY', 'ERI', 'ESP', 'EST', 'ETH', 'FIN', 'FJI', 'FRA', 'FSM', 'GAB', 'GBR', 'GEO', 'GHA', 'GIN', 'GMB', 'GNB', 'GNQ', 'GRC', 'GRD', 'GTM', 'GUY', 'HND', 'HRV', 'HTI', 'HUN', 'IDN', 'IND', 'IRL', 'IRN', 'IRQ', 'ISL', 'ISR', 'ITA', 'JAM', 'JOR', 'JPN', 'KAZ', 'KEN', 'KGZ', 'KHM', 'KIR', 'KOR', 'KWT', 'LAO', 'LBN', 'LBR', 'LBY', 'LCA', 'LKA', 'LSO', 'LTU', 'LUX', 'LVA', 'MAR', 'MDA', 'MDG', 'MDV', 'MEX', 'MKD', 'MLI', 'MLT', 'MMR', 'MNE', 'MNG', 'MOZ', 'MRT', 'MUS', 'MWI', 'MYS', 'NAM', 'NER', 'NGA', 'NIC', 'NLD', 'NOR', 'NPL', 'NZL', 'OMN', 'PAK', 'PAN', 'PER', 'PHL', 'PNG', 'POL', 'PRK', 'PRT', 'PRY', 'QAT', 'ROU', 'RUS', 'RWA', 'SAU', 'SDN', 'SEN', 'SGP', 'SLB', 'SLE', 'SLV', 'SOM', 'SRB', 'SSD', 'STP', 'SUR', 'SVK', 'SVN', 'SWE', 'SWZ', 'SYC', 'SYR', 'TCD', 'TGO', 'THA', 'TJK', 'TKM', 'TLS', 'TON', 'TTO', 'TUN', 'TUR', 'TZA', 'UGA', 'UKR', 'URY', 'USA', 'UZB', 'VCT', 'VEN', 'VNM', 'VUT', 'WSM', 'YEM', 'ZAF', 'ZMB', 'ZWE']
# Loading and filtering data...
# [I 2025-02-14 09:39:39,519] A new study created in memory with name: no-name-356c94ad-c198-48fd-aa28-038322ee429e
# Processing environment and socioeconomic data...
# Merging environment, socioeconomic, and air pollution data...
# Merged data has 183 rows and 12 columns.
#     Country Code  transportation          coal      cropland  \
# 0            AFG    5.728724e+07  1.237991e+07  3.047164e+07
# 1            AGO    1.657005e+08  0.000000e+00  7.027087e+07
# 2            ALB    2.535625e+07  3.709218e+05  1.866232e+06
# 3            ARE    5.190228e+08  0.000000e+00  1.601377e+05
# 4            ARG    6.409067e+08  1.997271e+05  7.706948e+08
# ..           ...             ...           ...           ...
# 178          WSM    2.020644e+06  0.000000e+00  1.023950e+04
# 179          YEM    5.327802e+07  0.000000e+00  4.579051e+06
# 180          ZAF    7.030688e+08  6.454257e+08  2.564283e+08
# 181          ZMB    7.106907e+07  7.678397e+05  6.251026e+07
# 182          ZWE    5.908101e+07  1.238390e+07  4.548359e+07
#
#      residential_commercial  forest_clearing  petrochemicals  \
# 0              8.294334e+06     8.632059e+04    0.000000e+00
# 1              4.872556e+07     1.024659e+09    0.000000e+00
# 2              1.147137e+07     4.995076e+06    0.000000e+00
# 3              9.554346e+06     0.000000e+00    7.280612e+07
# 4              5.821784e+08     4.487951e+08    1.150682e+07
# ..                      ...              ...             ...
# 178            7.913560e+05     0.000000e+00    0.000000e+00
# 179            4.013655e+07     8.444122e+02    0.000000e+00
# 180            3.673914e+08     2.595807e+08    2.056768e+07
# 181            3.337809e+06     5.333158e+08    0.000000e+00
# 182            9.166988e+06     5.094328e+07    0.000000e+00
#
#      electricity_generation  incineration_open_burning  health_expenditure  \
# 0              1.929000e+06               6.095110e+05          299.787491
# 1              3.753900e+07               5.018776e+05          182.326689
# 2              0.000000e+00               2.078827e+05          896.791354
# 3              1.217688e+09               1.615316e+06         3002.587776
# 4              7.590450e+08               2.238038e+06         2401.319013
# ..                      ...                        ...                 ...
# 178            1.296000e+06               2.874328e+03          300.072408
# 179            3.254100e+07               8.633200e+04                 NaN
# 180            3.140103e+09               2.139114e+07         1158.598532
# 181            2.685000e+07               1.808000e+05          167.320970
# 182            7.680600e+07               2.292942e+05          111.078436
#
#      urban_population  FactValueNumeric
# 0           9353296.0          44151.00
# 1          20488542.0          16997.28
# 2           1728969.0           6088.43
# 3           7908257.0           3599.55
# 4          40877099.0          34992.30
# ..                ...               ...
# 178           38256.0             86.13
# 179        11282260.0          26334.72
# 180        38047715.0          41118.60
# 181         7762359.0           7051.77
# 182         4848158.0           6990.00
#
# [183 rows x 12 columns]
# [I 2025-02-14 09:39:40,614] Trial 0 finished with value: 0.4119934586571752 and parameters: {'n_estimators': 1900, 'learning_rate': 0.005491782709238632, 'max_depth': 6, 'min_child_weight': 8, 'subsample': 0.9633699225861454, 'colsample_bytree': 0.9566313131181996, 'reg_alpha': 4.4512975043628815, 'reg_lambda': 4.375477171771557, 'gamma': 1.4993891841801352}. Best is trial 0 with value: 0.4119934586571752.
# [I 2025-02-14 09:39:41,748] Trial 1 finished with value: 0.5031650977598565 and parameters: {'n_estimators': 2200, 'learning_rate': 0.005122383002673764, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9549301393544207, 'colsample_bytree': 0.9505926110964341, 'reg_alpha': 2.6476385416019146, 'reg_lambda': 4.20831751514307, 'gamma': 3.5714392516598226}. Best is trial 1 with value: 0.5031650977598565.
# [I 2025-02-14 09:39:42,607] Trial 2 finished with value: 0.4873394240942581 and parameters: {'n_estimators': 1800, 'learning_rate': 0.005326555199126574, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9866991969379375, 'colsample_bytree': 0.9902404022143023, 'reg_alpha': 4.570566517020014, 'reg_lambda': 5.350601850584296, 'gamma': 2.446403320860658}. Best is trial 1 with value: 0.5031650977598565.
# [I 2025-02-14 09:39:43,000] Trial 3 finished with value: 0.3383694808290483 and parameters: {'n_estimators': 1600, 'learning_rate': 0.007877936192182997, 'max_depth': 6, 'min_child_weight': 6, 'subsample': 0.9656263986689023, 'colsample_bytree': 0.987012932560915, 'reg_alpha': 6.4706266354871484, 'reg_lambda': 5.690027599589907, 'gamma': 2.9090889896034935}. Best is trial 1 with value: 0.5031650977598565.
# [I 2025-02-14 09:39:43,340] Trial 4 finished with value: 0.35517978870651434 and parameters: {'n_estimators': 1900, 'learning_rate': 0.007675613495498614, 'max_depth': 7, 'min_child_weight': 8, 'subsample': 0.9678015644994131, 'colsample_bytree': 0.9601919245569289, 'reg_alpha': 2.5271644722090874, 'reg_lambda': 2.1029894291450786, 'gamma': 1.1935302792712315}. Best is trial 1 with value: 0.5031650977598565.
# [I 2025-02-14 09:39:43,684] Trial 5 finished with value: 0.3564951327998649 and parameters: {'n_estimators': 1500, 'learning_rate': 0.008699313899564166, 'max_depth': 6, 'min_child_weight': 8, 'subsample': 0.9881765609861904, 'colsample_bytree': 0.9567317138705913, 'reg_alpha': 3.0774603787164363, 'reg_lambda': 2.761413271216461, 'gamma': 2.265702919699188}. Best is trial 1 with value: 0.5031650977598565.
# [I 2025-02-14 09:39:44,582] Trial 6 finished with value: 0.4018476653210856 and parameters: {'n_estimators': 1500, 'learning_rate': 0.005977274754951982, 'max_depth': 6, 'min_child_weight': 8, 'subsample': 0.9817466997409291, 'colsample_bytree': 0.9912818087103902, 'reg_alpha': 6.840096694369565, 'reg_lambda': 5.453055550605358, 'gamma': 2.551924401662782}. Best is trial 1 with value: 0.5031650977598565.
# [I 2025-02-14 09:39:45,727] Trial 7 finished with value: 0.45563717986248453 and parameters: {'n_estimators': 2000, 'learning_rate': 0.0054692053909498484, 'max_depth': 7, 'min_child_weight': 10, 'subsample': 0.9941832420929064, 'colsample_bytree': 0.9938466915147546, 'reg_alpha': 7.484204414142329, 'reg_lambda': 4.071246516331826, 'gamma': 1.7546908929773246}. Best is trial 1 with value: 0.5031650977598565.
# [I 2025-02-14 09:39:46,396] Trial 8 finished with value: 0.5055964919622398 and parameters: {'n_estimators': 1600, 'learning_rate': 0.007326415711259303, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9851088585978701, 'colsample_bytree': 0.9587754292669088, 'reg_alpha': 6.129558988930725, 'reg_lambda': 3.216099556770999, 'gamma': 2.0117916750467533}. Best is trial 8 with value: 0.5055964919622398.
# [I 2025-02-14 09:39:53,100] Trial 16 finished with value: 0.5231133654514608 and parameters: {'n_estimators': 2100, 'learning_rate': 0.006195998705672169, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9699416022263309, 'colsample_bytree': 0.9994635803832935, 'reg_alpha': 3.9455086061136773, 'reg_lambda': 3.569726140258206, 'gamma': 2.9075028677366324}. Best is trial 12 with value: 0.5366890422201906.
# [I 2025-02-14 09:39:54,127] Trial 17 finished with value: 0.4980397075087759 and parameters: {'n_estimators': 2200, 'learning_rate': 0.006998493799422139, 'max_depth': 7, 'min_child_weight': 10, 'subsample': 0.9797589807287279, 'colsample_bytree': 0.9502549614881899, 'reg_alpha': 5.4196985749225846, 'reg_lambda': 4.493968266129572, 'gamma': 3.522868550606398}. Best is trial 12 with value: 0.5366890422201906.
# [I 2025-02-14 09:39:54,713] Trial 18 finished with value: 0.45062395482052786 and parameters: {'n_estimators': 2000, 'learning_rate': 0.0058374314632257795, 'max_depth': 6, 'min_child_weight': 7, 'subsample': 0.9606246810305079, 'colsample_bytree': 0.9777649762324597, 'reg_alpha': 3.3888132920121365, 'reg_lambda': 2.73611263070715, 'gamma': 2.86978966756013}. Best is trial 12 with value: 0.5366890422201906.
# [I 2025-02-14 09:39:55,623] Trial 19 finished with value: 0.5161851957243253 and parameters: {'n_estimators': 2000, 'learning_rate': 0.0064052715270526, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9717285393113393, 'colsample_bytree': 0.9641899716009389, 'reg_alpha': 5.091800902130226, 'reg_lambda': 4.914922319645058, 'gamma': 3.6879906332533188}. Best is trial 12 with value: 0.5366890422201906.
# [I 2025-02-14 09:39:56,525] Trial 20 finished with value: 0.4980801198195378 and parameters: {'n_estimators': 2100, 'learning_rate': 0.008363581461311392, 'max_depth': 7, 'min_child_weight': 10, 'subsample': 0.978853392951992, 'colsample_bytree': 0.9685612427357331, 'reg_alpha': 3.8768917737280946, 'reg_lambda': 3.7772238251802364, 'gamma': 3.2595624390054647}. Best is trial 12 with value: 0.5366890422201906.
# [I 2025-02-14 09:39:57,498] Trial 21 finished with value: 0.5308621249164287 and parameters: {'n_estimators': 2200, 'learning_rate': 0.006156286119822655, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9696523764104908, 'colsample_bytree': 0.9989801108829355, 'reg_alpha': 4.080724019000008, 'reg_lambda': 3.7042947775298365, 'gamma': 2.8183290230244924}. Best is trial 12 with value: 0.5366890422201906.
# [I 2025-02-14 09:39:58,473] Trial 22 finished with value: 0.5420028416823409 and parameters: {'n_estimators': 2200, 'learning_rate': 0.0068745826952460905, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9583366281877932, 'colsample_bytree': 0.9994362255529665, 'reg_alpha': 3.002153774492295, 'reg_lambda': 2.8592763022564247, 'gamma': 2.692817272379037}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:39:59,183] Trial 23 finished with value: 0.5130373006191189 and parameters: {'n_estimators': 2200, 'learning_rate': 0.0070788150433792685, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9610159781210471, 'colsample_bytree': 0.9996765370713947, 'reg_alpha': 2.837613140288335, 'reg_lambda': 2.7395403147087007, 'gamma': 2.6723842042116184}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:39:59,664] Trial 24 finished with value: 0.3929442789885663 and parameters: {'n_estimators': 2100, 'learning_rate': 0.006827290169672698, 'max_depth': 6, 'min_child_weight': 8, 'subsample': 0.9574947196854959, 'colsample_bytree': 0.9955610096918523, 'reg_alpha': 2.2181193501127274, 'reg_lambda': 3.07028730267509, 'gamma': 3.0559183319759953}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:40:00,655] Trial 25 finished with value: 0.5250540149098875 and parameters: {'n_estimators': 2000, 'learning_rate': 0.007599084225781694, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9709401265874155, 'colsample_bytree': 0.981759383131852, 'reg_alpha': 4.2786117052815955, 'reg_lambda': 2.4241686990084563, 'gamma': 2.707307920105591}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:40:01,568] Trial 26 finished with value: 0.4861629434519247 and parameters: {'n_estimators': 2200, 'learning_rate': 0.006108599973139279, 'max_depth': 6, 'min_child_weight': 10, 'subsample': 0.9659012514527866, 'colsample_bytree': 0.9735159907042237, 'reg_alpha': 3.131038380945214, 'reg_lambda': 4.836412107786821, 'gamma': 2.2717378372509636}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:40:02,004] Trial 27 finished with value: 0.37749367851690163 and parameters: {'n_estimators': 2100, 'learning_rate': 0.006274820029772944, 'max_depth': 6, 'min_child_weight': 8, 'subsample': 0.9769931343799476, 'colsample_bytree': 0.9963041645914871, 'reg_alpha': 5.22562284082658, 'reg_lambda': 3.8496909577182783, 'gamma': 3.4387189482889315}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:40:02,761] Trial 28 finished with value: 0.5047003195232409 and parameters: {'n_estimators': 1800, 'learning_rate': 0.005796387488908181, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.983569569697507, 'colsample_bytree': 0.9895550663616411, 'reg_alpha': 4.112433668452616, 'reg_lambda': 3.071475120934985, 'gamma': 3.0909469992962864}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:40:03,229] Trial 29 finished with value: 0.394543070204069 and parameters: {'n_estimators': 2200, 'learning_rate': 0.007366018311065927, 'max_depth': 6, 'min_child_weight': 8, 'subsample': 0.9617770138910626, 'colsample_bytree': 0.9773501035744461, 'reg_alpha': 3.673850614032737, 'reg_lambda': 4.288929159946272, 'gamma': 2.2940830111154087}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:40:03,700] Trial 30 finished with value: 0.4074126180477783 and parameters: {'n_estimators': 1900, 'learning_rate': 0.006935048580965309, 'max_depth': 6, 'min_child_weight': 6, 'subsample': 0.9640256710443035, 'colsample_bytree': 0.963538423433615, 'reg_alpha': 4.612033060198871, 'reg_lambda': 2.4251337581924064, 'gamma': 2.749436016903397}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:40:04,613] Trial 31 finished with value: 0.5329471317866374 and parameters: {'n_estimators': 2200, 'learning_rate': 0.006505246706653995, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9501160146264712, 'colsample_bytree': 0.952370594705173, 'reg_alpha': 3.235524055467837, 'reg_lambda': 3.5262967878746885, 'gamma': 3.7110732194316958}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:40:05,245] Trial 32 finished with value: 0.4843010655636264 and parameters: {'n_estimators': 2100, 'learning_rate': 0.006687886592666783, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9539480491774655, 'colsample_bytree': 0.9543364951874175, 'reg_alpha': 2.926345837656272, 'reg_lambda': 3.4670414994600036, 'gamma': 3.4067535860018587}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:40:06,141] Trial 33 finished with value: 0.5213780362731992 and parameters: {'n_estimators': 2200, 'learning_rate': 0.006419167900188883, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9561175976731442, 'colsample_bytree': 0.9539383623588653, 'reg_alpha': 2.5250920006473083, 'reg_lambda': 4.556226916672668, 'gamma': 3.050732197558956}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:40:07,061] Trial 34 finished with value: 0.42709376142484956 and parameters: {'n_estimators': 2200, 'learning_rate': 0.005295495772276925, 'max_depth': 6, 'min_child_weight': 8, 'subsample': 0.9596179091328125, 'colsample_bytree': 0.9605659074411139, 'reg_alpha': 4.438711194429139, 'reg_lambda': 4.046270482713363, 'gamma': 2.4498287988549245}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:40:07,751] Trial 35 finished with value: 0.48830878300050296 and parameters: {'n_estimators': 2100, 'learning_rate': 0.005977181084396463, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9535626729204641, 'colsample_bytree': 0.9925902699316574, 'reg_alpha': 3.5910406302102453, 'reg_lambda': 2.9084055405153277, 'gamma': 3.638031669951428}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:40:08,879] Trial 36 finished with value: 0.4859718560234221 and parameters: {'n_estimators': 2200, 'learning_rate': 0.005088544882317408, 'max_depth': 6, 'min_child_weight': 10, 'subsample': 0.968945403083724, 'colsample_bytree': 0.9880755465007927, 'reg_alpha': 3.1934000598680212, 'reg_lambda': 2.3548929995344206, 'gamma': 1.0705691508962403}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:40:09,668] Trial 37 finished with value: 0.5260614293818955 and parameters: {'n_estimators': 2000, 'learning_rate': 0.008202529590247627, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9661084769239484, 'colsample_bytree': 0.9964008630065404, 'reg_alpha': 2.558628438233292, 'reg_lambda': 3.531467851642554, 'gamma': 2.567245088291825}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:40:10,215] Trial 38 finished with value: 0.3798104979236978 and parameters: {'n_estimators': 2200, 'learning_rate': 0.0067881762596147125, 'max_depth': 6, 'min_child_weight': 8, 'subsample': 0.9882216576587766, 'colsample_bytree': 0.9848675343438623, 'reg_alpha': 2.019756341977098, 'reg_lambda': 3.957355918084404, 'gamma': 1.4025700759641482}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:40:11,257] Trial 39 finished with value: 0.4615103270103659 and parameters: {'n_estimators': 1700, 'learning_rate': 0.0059915586845289545, 'max_depth': 6, 'min_child_weight': 10, 'subsample': 0.9732594502040129, 'colsample_bytree': 0.9542665443170533, 'reg_alpha': 4.844831707596997, 'reg_lambda': 5.341288301291399, 'gamma': 2.8452154788648385}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:40:12,428] Trial 40 finished with value: 0.5391726951880156 and parameters: {'n_estimators': 2100, 'learning_rate': 0.007382866762817816, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9504288377934649, 'colsample_bytree': 0.9582411843409677, 'reg_alpha': 2.7814825352803547, 'reg_lambda': 3.311042591300672, 'gamma': 3.0788719129478803}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:40:13,643] Trial 41 finished with value: 0.5309912814450055 and parameters: {'n_estimators': 2200, 'learning_rate': 0.007704814600321783, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9516923981070172, 'colsample_bytree': 0.9596915347409577, 'reg_alpha': 2.9190829618165135, 'reg_lambda': 3.2522065962963493, 'gamma': 3.1221192199142407}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:40:14,420] Trial 42 finished with value: 0.5018365206102431 and parameters: {'n_estimators': 2100, 'learning_rate': 0.007797728234635263, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9504999902709005, 'colsample_bytree': 0.9582474708445093, 'reg_alpha': 2.7227759275264343, 'reg_lambda': 3.2815661147535966, 'gamma': 3.1347924697833895}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:40:14,994] Trial 43 finished with value: 0.4050040978907833 and parameters: {'n_estimators': 2200, 'learning_rate': 0.007476152263003344, 'max_depth': 6, 'min_child_weight': 8, 'subsample': 0.9532299089882534, 'colsample_bytree': 0.9613475457069766, 'reg_alpha': 2.363963424176367, 'reg_lambda': 2.629264585817923, 'gamma': 3.397299208490288}. Best is trial 22 with value: 0.5420028416823409.
# [I 2025-02-14 09:40:16,101] Trial 44 finished with value: 0.5467390599077289 and parameters: {'n_estimators': 2100, 'learning_rate': 0.008080945272650348, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9581129192910857, 'colsample_bytree': 0.956116844361253, 'reg_alpha': 3.1656808097762204, 'reg_lambda': 3.0076732316067574, 'gamma': 2.977571235370204}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:17,076] Trial 45 finished with value: 0.526998896944667 and parameters: {'n_estimators': 2000, 'learning_rate': 0.008448499646022683, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9583696692629615, 'colsample_bytree': 0.9558011054600226, 'reg_alpha': 3.2657198076166223, 'reg_lambda': 2.921425405973162, 'gamma': 2.9820150125865608}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:17,934] Trial 46 finished with value: 0.48979785615062754 and parameters: {'n_estimators': 2100, 'learning_rate': 0.00815390687224181, 'max_depth': 6, 'min_child_weight': 10, 'subsample': 0.9540748393506338, 'colsample_bytree': 0.9567916453685762, 'reg_alpha': 3.732524628772195, 'reg_lambda': 2.2602752627412377, 'gamma': 2.6181538962422777}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:19,093] Trial 47 finished with value: 0.5422224904170967 and parameters: {'n_estimators': 2100, 'learning_rate': 0.008932935356952214, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.9555376517410591, 'colsample_bytree': 0.9522672521616784, 'reg_alpha': 7.517937784723085, 'reg_lambda': 6.353278579752688, 'gamma': 2.0284105437787887}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:19,597] Trial 48 finished with value: 0.38986232065703386 and parameters: {'n_estimators': 1900, 'learning_rate': 0.007924912947606833, 'max_depth': 7, 'min_child_weight': 8, 'subsample': 0.9555460784357166, 'colsample_bytree': 0.968005422551546, 'reg_alpha': 6.954690486778639, 'reg_lambda': 6.4170385136934405, 'gamma': 1.8246120683243081}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:20,709] Trial 49 finished with value: 0.5331819926025507 and parameters: {'n_estimators': 2000, 'learning_rate': 0.008952421422664305, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.9632900121055241, 'colsample_bytree': 0.9634302198162675, 'reg_alpha': 5.896210769831265, 'reg_lambda': 7.973856742616984, 'gamma': 2.1573383444418925}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:21,203] Trial 50 finished with value: 0.4194696566274536 and parameters: {'n_estimators': 2100, 'learning_rate': 0.00872539248110283, 'max_depth': 7, 'min_child_weight': 7, 'subsample': 0.9585404660112914, 'colsample_bytree': 0.9519986446916361, 'reg_alpha': 7.8265366330249595, 'reg_lambda': 6.1067500537286055, 'gamma': 1.7782572764771276}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:22,337] Trial 51 finished with value: 0.5311866973231578 and parameters: {'n_estimators': 2000, 'learning_rate': 0.008692866474827797, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.9621880878574112, 'colsample_bytree': 0.9627867849551835, 'reg_alpha': 6.37319392246233, 'reg_lambda': 7.884495211798126, 'gamma': 2.098807783342267}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:23,144] Trial 52 finished with value: 0.4973365160767289 and parameters: {'n_estimators': 2000, 'learning_rate': 0.008962844500566803, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.9565037019991048, 'colsample_bytree': 0.9650348303204734, 'reg_alpha': 6.811657141169443, 'reg_lambda': 7.01056061838266, 'gamma': 2.1510498956255066}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:24,332] Trial 53 finished with value: 0.5343312636196486 and parameters: {'n_estimators': 2100, 'learning_rate': 0.00808679820457212, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.9529787261158801, 'colsample_bytree': 0.970283724252157, 'reg_alpha': 7.371467212686697, 'reg_lambda': 6.906778756095595, 'gamma': 1.9280389552016635}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:25,370] Trial 54 finished with value: 0.4725091010242767 and parameters: {'n_estimators': 2100, 'learning_rate': 0.007236726141272416, 'max_depth': 7, 'min_child_weight': 10, 'subsample': 0.9521550507286929, 'colsample_bytree': 0.9712397693793045, 'reg_alpha': 7.12668938993192, 'reg_lambda': 7.175208194750081, 'gamma': 1.568291884066367}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:26,186] Trial 55 finished with value: 0.4862421141591068 and parameters: {'n_estimators': 2100, 'learning_rate': 0.007993887934926877, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.9558280418811039, 'colsample_bytree': 0.9669434992150419, 'reg_alpha': 7.745652945771206, 'reg_lambda': 6.496238087987682, 'gamma': 1.9458904187922765}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:26,997] Trial 56 finished with value: 0.4924253953318468 and parameters: {'n_estimators': 2100, 'learning_rate': 0.008465580760535659, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.9597404885118676, 'colsample_bytree': 0.9747485505620785, 'reg_alpha': 7.3921114628032525, 'reg_lambda': 6.794263374411993, 'gamma': 2.476962603202736}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:28,298] Trial 57 finished with value: 0.48062036316905876 and parameters: {'n_estimators': 1800, 'learning_rate': 0.0075668048349810755, 'max_depth': 7, 'min_child_weight': 10, 'subsample': 0.9549922426401203, 'colsample_bytree': 0.9715399001510587, 'reg_alpha': 7.528501855187272, 'reg_lambda': 5.834115305623015, 'gamma': 1.6242096302788942}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:29,611] Trial 58 finished with value: 0.4381345272326065 and parameters: {'n_estimators': 1600, 'learning_rate': 0.008289722057591637, 'max_depth': 7, 'min_child_weight': 8, 'subsample': 0.9766354527012907, 'colsample_bytree': 0.9576596202640734, 'reg_alpha': 5.468140783245484, 'reg_lambda': 5.476718463323178, 'gamma': 1.3733896464289543}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:31,706] Trial 59 finished with value: 0.5107698536439592 and parameters: {'n_estimators': 2100, 'learning_rate': 0.00709649330065879, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.952354379057294, 'colsample_bytree': 0.9702231823602088, 'reg_alpha': 6.482366690292206, 'reg_lambda': 7.633971137699944, 'gamma': 2.950466038860519}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:33,055] Trial 60 finished with value: 0.5277651431045367 and parameters: {'n_estimators': 2100, 'learning_rate': 0.007994776396334946, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.9678146721163626, 'colsample_bytree': 0.9775223335478549, 'reg_alpha': 3.0128207422357276, 'reg_lambda': 2.5917209358582305, 'gamma': 2.327608551870726}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:34,633] Trial 61 finished with value: 0.5380113040092755 and parameters: {'n_estimators': 2000, 'learning_rate': 0.008935323499581671, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.9636247127033921, 'colsample_bytree': 0.9625747953219754, 'reg_alpha': 6.1328680720530695, 'reg_lambda': 7.3357151468008075, 'gamma': 1.8865721316833484}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:36,249] Trial 62 finished with value: 0.5343338872589509 and parameters: {'n_estimators': 2000, 'learning_rate': 0.00864869649383069, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.9579367220955881, 'colsample_bytree': 0.9590719450935079, 'reg_alpha': 7.222360462687916, 'reg_lambda': 7.325003064496605, 'gamma': 1.6486074232957646}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:37,712] Trial 63 finished with value: 0.5264021748919512 and parameters: {'n_estimators': 1900, 'learning_rate': 0.008615150047319962, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.9639701490192524, 'colsample_bytree': 0.9591053309474661, 'reg_alpha': 6.705854566526298, 'reg_lambda': 7.426479160603995, 'gamma': 1.687634775380351}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:39,302] Trial 64 finished with value: 0.5383504900312859 and parameters: {'n_estimators': 2000, 'learning_rate': 0.008843170971569295, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.9576969595037036, 'colsample_bytree': 0.9620790430648459, 'reg_alpha': 7.153676575547416, 'reg_lambda': 7.360404435191994, 'gamma': 1.3571104411189245}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:40,420] Trial 65 finished with value: 0.5024537266505607 and parameters: {'n_estimators': 1900, 'learning_rate': 0.008917479571325132, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.9812685678423841, 'colsample_bytree': 0.9557345643419977, 'reg_alpha': 6.023053780585537, 'reg_lambda': 6.7047239548880295, 'gamma': 3.225312526851511}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:42,098] Trial 66 finished with value: 0.5342860911204395 and parameters: {'n_estimators': 2000, 'learning_rate': 0.008836286812381482, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.9598703873040814, 'colsample_bytree': 0.9621930611160676, 'reg_alpha': 5.713196037176294, 'reg_lambda': 7.72586162933092, 'gamma': 1.2485026239117851}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:42,938] Trial 67 finished with value: 0.417877409907061 and parameters: {'n_estimators': 2200, 'learning_rate': 0.008535862222291241, 'max_depth': 6, 'min_child_weight': 8, 'subsample': 0.9570452854696232, 'colsample_bytree': 0.9521885016909957, 'reg_alpha': 6.293382230505509, 'reg_lambda': 3.025016878245783, 'gamma': 2.7653524527138704}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:44,129] Trial 68 finished with value: 0.4826403638297122 and parameters: {'n_estimators': 2000, 'learning_rate': 0.008355630033839094, 'max_depth': 6, 'min_child_weight': 10, 'subsample': 0.9618360044728552, 'colsample_bytree': 0.9660147644608326, 'reg_alpha': 7.946012232141743, 'reg_lambda': 2.0157287718994015, 'gamma': 1.0152408455129796}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:45,371] Trial 69 finished with value: 0.4982510177630015 and parameters: {'n_estimators': 1900, 'learning_rate': 0.008761576374016481, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.973256971109213, 'colsample_bytree': 0.9606550648185965, 'reg_alpha': 2.7792182888551196, 'reg_lambda': 7.476451996562751, 'gamma': 3.2937821136950958}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:46,601] Trial 70 finished with value: 0.41633526048769454 and parameters: {'n_estimators': 2200, 'learning_rate': 0.006880341328645339, 'max_depth': 6, 'min_child_weight': 8, 'subsample': 0.9547428105472845, 'colsample_bytree': 0.9569852461788012, 'reg_alpha': 2.3905384532291865, 'reg_lambda': 3.350418620291014, 'gamma': 1.423134554379652}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:48,111] Trial 71 finished with value: 0.533350959698917 and parameters: {'n_estimators': 2000, 'learning_rate': 0.008610089658079747, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.9587238909178029, 'colsample_bytree': 0.9590141194538823, 'reg_alpha': 7.174677445760433, 'reg_lambda': 7.308248630343927, 'gamma': 1.502876534024952}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:48,946] Trial 72 finished with value: 0.5006691400701674 and parameters: {'n_estimators': 2000, 'learning_rate': 0.008980315651746834, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.9574518700106792, 'colsample_bytree': 0.961908822040849, 'reg_alpha': 7.6337937122997666, 'reg_lambda': 6.638500808204009, 'gamma': 1.8622409579987567}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:50,131] Trial 73 finished with value: 0.5061673840500194 and parameters: {'n_estimators': 2000, 'learning_rate': 0.006622571058432172, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.9655083920703554, 'colsample_bytree': 0.9532995574184104, 'reg_alpha': 7.21389156221027, 'reg_lambda': 7.041752242434156, 'gamma': 1.3006964890660773}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:51,315] Trial 74 finished with value: 0.5401042623811676 and parameters: {'n_estimators': 2100, 'learning_rate': 0.008777184193162554, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.9611524958496148, 'colsample_bytree': 0.9553089564836752, 'reg_alpha': 6.556900345131898, 'reg_lambda': 7.363969480231565, 'gamma': 1.6844529751203625}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:52,164] Trial 75 finished with value: 0.5028336097549946 and parameters: {'n_estimators': 2100, 'learning_rate': 0.008274766278751703, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.9605212556874816, 'colsample_bytree': 0.9500690640107516, 'reg_alpha': 6.685712725511018, 'reg_lambda': 4.649530604538887, 'gamma': 2.376225500523329}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:53,407] Trial 76 finished with value: 0.5152704504591649 and parameters: {'n_estimators': 2100, 'learning_rate': 0.006348220579307542, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9953676557664153, 'colsample_bytree': 0.9559135709172227, 'reg_alpha': 3.426128438682141, 'reg_lambda': 5.8981050763981635, 'gamma': 2.9728721952634363}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:54,370] Trial 77 finished with value: 0.4697384620119005 and parameters: {'n_estimators': 2200, 'learning_rate': 0.008455532933012396, 'max_depth': 6, 'min_child_weight': 10, 'subsample': 0.9651795709857746, 'colsample_bytree': 0.9550121756951813, 'reg_alpha': 6.516525902804097, 'reg_lambda': 7.167204447916823, 'gamma': 1.504598211684452}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:56,046] Trial 78 finished with value: 0.5360898122423032 and parameters: {'n_estimators': 2200, 'learning_rate': 0.0073616089256595425, 'max_depth': 7, 'min_child_weight': 9, 'subsample': 0.9620842365583273, 'colsample_bytree': 0.9648635443835774, 'reg_alpha': 7.013789325047136, 'reg_lambda': 5.148886663814364, 'gamma': 1.7179436723162658}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:56,656] Trial 79 finished with value: 0.3393813281821968 and parameters: {'n_estimators': 2100, 'learning_rate': 0.008805293673029709, 'max_depth': 6, 'min_child_weight': 6, 'subsample': 0.9509295520373429, 'colsample_bytree': 0.9514172836227541, 'reg_alpha': 3.117180059976428, 'reg_lambda': 7.803970073998967, 'gamma': 2.0110118105266706}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:57,929] Trial 80 finished with value: 0.5380937331961633 and parameters: {'n_estimators': 2100, 'learning_rate': 0.00700923232751024, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9766520231493693, 'colsample_bytree': 0.9532412912273026, 'reg_alpha': 6.1816435256664795, 'reg_lambda': 2.8346089228266527, 'gamma': 1.1734349990848876}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:58,638] Trial 81 finished with value: 0.48686920943948886 and parameters: {'n_estimators': 2100, 'learning_rate': 0.0069959911739364946, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9770199783204273, 'colsample_bytree': 0.9537249450537533, 'reg_alpha': 6.185079151613988, 'reg_lambda': 2.8296227960139726, 'gamma': 1.1329659706860373}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:40:59,405] Trial 82 finished with value: 0.49623436581642244 and parameters: {'n_estimators': 2100, 'learning_rate': 0.006792978543066668, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9802046316947768, 'colsample_bytree': 0.9580613978458683, 'reg_alpha': 5.674247894309535, 'reg_lambda': 3.13257170025553, 'gamma': 1.2340323828873005}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:41:00,305] Trial 83 finished with value: 0.5115209235450986 and parameters: {'n_estimators': 2200, 'learning_rate': 0.007188899829876046, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9784721505428395, 'colsample_bytree': 0.9606511636575399, 'reg_alpha': 2.6490564321287557, 'reg_lambda': 2.591106847318997, 'gamma': 2.6662359137230287}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:41:01,431] Trial 84 finished with value: 0.5412739463050351 and parameters: {'n_estimators': 2100, 'learning_rate': 0.0074828317821249, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9758419490918779, 'colsample_bytree': 0.9512027644462134, 'reg_alpha': 6.074404274791875, 'reg_lambda': 3.4396642196213754, 'gamma': 1.3468915572015379}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:41:02,225] Trial 85 finished with value: 0.5083379147095618 and parameters: {'n_estimators': 2100, 'learning_rate': 0.00770993529240986, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9749638051035598, 'colsample_bytree': 0.9529248590521388, 'reg_alpha': 6.13731940546273, 'reg_lambda': 2.224215581596264, 'gamma': 1.160417390419197}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:41:03,329] Trial 86 finished with value: 0.5416018406752234 and parameters: {'n_estimators': 2100, 'learning_rate': 0.007272171144277507, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9720277543245803, 'colsample_bytree': 0.9511425665690171, 'reg_alpha': 6.676638236192897, 'reg_lambda': 3.6340970517168345, 'gamma': 1.3251581364299703}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:41:04,120] Trial 87 finished with value: 0.5035159940103564 and parameters: {'n_estimators': 2100, 'learning_rate': 0.007553871915690636, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.971503843058419, 'colsample_bytree': 0.9509579674803276, 'reg_alpha': 6.6391962684099575, 'reg_lambda': 3.73643830216771, 'gamma': 1.2920472413413526}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:41:05,227] Trial 88 finished with value: 0.538962732238075 and parameters: {'n_estimators': 2100, 'learning_rate': 0.007456176225455828, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9833924865010668, 'colsample_bytree': 0.9548652310615687, 'reg_alpha': 6.901576106406658, 'reg_lambda': 4.249918436139562, 'gamma': 1.3865772685649542}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:41:06,337] Trial 89 finished with value: 0.48934579614181795 and parameters: {'n_estimators': 2100, 'learning_rate': 0.007275420958784284, 'max_depth': 6, 'min_child_weight': 10, 'subsample': 0.9859271649732204, 'colsample_bytree': 0.9554444318423594, 'reg_alpha': 7.047180660079528, 'reg_lambda': 4.168367285805555, 'gamma': 1.3678429388286268}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:41:07,209] Trial 90 finished with value: 0.5082112702898901 and parameters: {'n_estimators': 2100, 'learning_rate': 0.007421647403669173, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9906409217837058, 'colsample_bytree': 0.9513210356253048, 'reg_alpha': 6.8229423550229304, 'reg_lambda': 3.895727182860758, 'gamma': 1.4481870183123353}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:41:08,054] Trial 91 finished with value: 0.5076774301685378 and parameters: {'n_estimators': 2100, 'learning_rate': 0.00777350498393537, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9841817339690855, 'colsample_bytree': 0.9545347679078703, 'reg_alpha': 6.8777180665479944, 'reg_lambda': 3.4195208068728973, 'gamma': 1.5780311432468888}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:41:09,180] Trial 92 finished with value: 0.5319254066258783 and parameters: {'n_estimators': 2100, 'learning_rate': 0.007095862616755405, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.982708310771983, 'colsample_bytree': 0.9529380132633726, 'reg_alpha': 6.340266886726248, 'reg_lambda': 2.9748992680750757, 'gamma': 1.1095174290146506}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:41:10,302] Trial 93 finished with value: 0.5449762722552358 and parameters: {'n_estimators': 2100, 'learning_rate': 0.007497204152675179, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9739595795526348, 'colsample_bytree': 0.9572453994093282, 'reg_alpha': 6.57213778279724, 'reg_lambda': 3.627215972517795, 'gamma': 1.3177618702295728}. Best is trial 44 with value: 0.5467390599077289.
# [I 2025-02-14 09:41:11,486] Trial 94 finished with value: 0.5477026348898588 and parameters: {'n_estimators': 2200, 'learning_rate': 0.007452093194816159, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9731603914959709, 'colsample_bytree': 0.9570363427137736, 'reg_alpha': 7.331042657688962, 'reg_lambda': 3.603160367980771, 'gamma': 1.3168645730519892}. Best is trial 94 with value: 0.5477026348898588.
# [I 2025-02-14 09:41:12,644] Trial 95 finished with value: 0.5464841680693439 and parameters: {'n_estimators': 2200, 'learning_rate': 0.007480246872173531, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.97311398160864, 'colsample_bytree': 0.9810146982492866, 'reg_alpha': 7.345501410326683, 'reg_lambda': 3.6260076611203984, 'gamma': 1.2899882880166058}. Best is trial 94 with value: 0.5477026348898588.
# [I 2025-02-14 09:41:13,979] Trial 96 finished with value: 0.5517222467578913 and parameters: {'n_estimators': 2200, 'learning_rate': 0.007640370552108352, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9737324595351116, 'colsample_bytree': 0.9812388957288867, 'reg_alpha': 7.405046226278978, 'reg_lambda': 3.646692412847594, 'gamma': 1.3080631053302108}. Best is trial 96 with value: 0.5517222467578913.
# [I 2025-02-14 09:41:14,814] Trial 97 finished with value: 0.4038220475214027 and parameters: {'n_estimators': 2200, 'learning_rate': 0.00760792441428152, 'max_depth': 6, 'min_child_weight': 8, 'subsample': 0.9734579693834188, 'colsample_bytree': 0.9800778815997273, 'reg_alpha': 7.381893335024203, 'reg_lambda': 3.619735202231899, 'gamma': 1.3055961414448782}. Best is trial 96 with value: 0.5517222467578913.
# [I 2025-02-14 09:41:15,730] Trial 98 finished with value: 0.5091905079520945 and parameters: {'n_estimators': 2200, 'learning_rate': 0.007869068746089641, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9703496626723138, 'colsample_bytree': 0.9863247170609327, 'reg_alpha': 7.61124114873342, 'reg_lambda': 4.054705543920839, 'gamma': 1.5301468649362762}. Best is trial 96 with value: 0.5517222467578913.
# [I 2025-02-14 09:41:16,605] Trial 99 finished with value: 0.4998795824821135 and parameters: {'n_estimators': 2200, 'learning_rate': 0.007250729428716585, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9723151253092797, 'colsample_bytree': 0.9799421762879816, 'reg_alpha': 7.982239115164482, 'reg_lambda': 3.806529103218211, 'gamma': 1.2169574398608511}. Best is trial 96 with value: 0.5517222467578913.
# Best parameters found:  {'n_estimators': 2200, 'learning_rate': 0.007640370552108352, 'max_depth': 6, 'min_child_weight': 9, 'subsample': 0.9737324595351116, 'colsample_bytree': 0.9812388957288867, 'reg_alpha': 7.405046226278978, 'reg_lambda': 3.646692412847594, 'gamma': 1.3080631053302108}
# [0]	validation_0-rmse:293400.41168
# [1]	validation_0-rmse:293059.91835
# [2]	validation_0-rmse:292699.78056
# [3]	validation_0-rmse:292387.82032
# [4]	validation_0-rmse:292031.21186
# [5]	validation_0-rmse:291676.41647
# [6]	validation_0-rmse:291323.71998
# [7]	validation_0-rmse:290973.09941
# [8]	validation_0-rmse:290624.52553
# [9]	validation_0-rmse:290278.12760
# [10]	validation_0-rmse:289933.85544
# [11]	validation_0-rmse:289591.59728
# [12]	validation_0-rmse:289251.46692
# [13]	validation_0-rmse:288913.45922
# [14]	validation_0-rmse:288577.45136
# [15]	validation_0-rmse:288243.42843
# [16]	validation_0-rmse:287951.01174
# [17]	validation_0-rmse:287619.89544
# [18]	validation_0-rmse:287290.91562
# [19]	validation_0-rmse:286999.98326
# [20]	validation_0-rmse:286710.52625
# [21]	validation_0-rmse:286412.98761
# [22]	validation_0-rmse:286090.08645
# [23]	validation_0-rmse:285771.52272
# [24]	validation_0-rmse:285452.40946
# [25]	validation_0-rmse:285135.22925
# [26]	validation_0-rmse:284819.87597
# [27]	validation_0-rmse:284506.46052
# [28]	validation_0-rmse:284194.83222
# [29]	validation_0-rmse:283885.13948
# [30]	validation_0-rmse:283577.26858
# [31]	validation_0-rmse:283271.23271
# [32]	validation_0-rmse:282967.07598
# [33]	validation_0-rmse:282664.19884
# [34]	validation_0-rmse:282374.37978
# [35]	validation_0-rmse:282075.41526
# [36]	validation_0-rmse:281778.22966
# [37]	validation_0-rmse:281482.83852
# [38]	validation_0-rmse:281189.09535
# [39]	validation_0-rmse:280919.15780
# [40]	validation_0-rmse:280628.09218
# [41]	validation_0-rmse:280338.71764
# [42]	validation_0-rmse:280050.86933
# [43]	validation_0-rmse:279764.72692
# [2029]	validation_0-rmse:27818.01574
# [2030]	validation_0-rmse:27816.97649
# [2031]	validation_0-rmse:27815.15504
# [2032]	validation_0-rmse:27818.87527
# [2033]	validation_0-rmse:27818.04929
# [2034]	validation_0-rmse:27814.04094
# [2035]	validation_0-rmse:27812.99063
# [2036]	validation_0-rmse:27815.08164
# [2037]	validation_0-rmse:27817.24678
# [2038]	validation_0-rmse:27814.55204
# [2039]	validation_0-rmse:27817.44791
# [2040]	validation_0-rmse:27819.46646
# [2041]	validation_0-rmse:27818.39865
# [2042]	validation_0-rmse:27820.29814
# [2043]	validation_0-rmse:27818.50199
# [2044]	validation_0-rmse:27814.46232
# [2045]	validation_0-rmse:27816.35263
# [2046]	validation_0-rmse:27818.32377
# [2047]	validation_0-rmse:27816.81329
# [2048]	validation_0-rmse:27818.66375
# [2049]	validation_0-rmse:27821.02247
# [2050]	validation_0-rmse:27819.18764
# [2051]	validation_0-rmse:27817.52664
# [2052]	validation_0-rmse:27816.42295
# [2053]	validation_0-rmse:27814.74561
# [2054]	validation_0-rmse:27813.64970
# [2055]	validation_0-rmse:27813.91345
# [2056]	validation_0-rmse:27813.01255
# [2057]	validation_0-rmse:27815.22035
# [2058]	validation_0-rmse:27814.49122
# [2059]	validation_0-rmse:27812.67526
# [2060]	validation_0-rmse:27811.73823
# [2061]	validation_0-rmse:27810.75873
# [2062]	validation_0-rmse:27806.85294
# [2063]	validation_0-rmse:27805.92365
# [2064]	validation_0-rmse:27809.61643
# [2065]	validation_0-rmse:27806.41576
# [2066]	validation_0-rmse:27805.74712
# [2067]	validation_0-rmse:27802.08486
# [2068]	validation_0-rmse:27801.18590
# [2069]	validation_0-rmse:27800.41037
# [2070]	validation_0-rmse:27797.68301
# [2071]	validation_0-rmse:27796.97903
# [2072]	validation_0-rmse:27798.87340
# [2073]	validation_0-rmse:27795.56660
# [2074]	validation_0-rmse:27794.56615
# [2075]	validation_0-rmse:27796.51603
# [2076]	validation_0-rmse:27796.75251
# [2077]	validation_0-rmse:27795.07298
# [2078]	validation_0-rmse:27793.26683
# [2079]	validation_0-rmse:27790.36359
# [2080]	validation_0-rmse:27794.13149
# [2081]	validation_0-rmse:27796.18017
# [2082]	validation_0-rmse:27794.29592
# [2083]	validation_0-rmse:27792.44986
# [2084]	validation_0-rmse:27794.86233
# [2085]	validation_0-rmse:27796.67873
# [2086]	validation_0-rmse:27799.09390
# [2087]	validation_0-rmse:27801.02133
# [2088]	validation_0-rmse:27797.23749
# [2089]	validation_0-rmse:27799.41971
# [2090]	validation_0-rmse:27801.42940
# [2091]	validation_0-rmse:27803.36037
# [2092]	validation_0-rmse:27799.64893
# [2093]	validation_0-rmse:27801.48999
# [2094]	validation_0-rmse:27803.37620
# [2095]	validation_0-rmse:27802.35659
# [2096]	validation_0-rmse:27804.34997
# [2097]	validation_0-rmse:27800.59641
# [2098]	validation_0-rmse:27797.49104
# [2099]	validation_0-rmse:27799.47958
# Final Train R^2 Score: 0.9943809826200993
# Final Test R^2 Score: 0.7663285167740033
# Script execution complete!
